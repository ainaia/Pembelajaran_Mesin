# %% [markdown]
# <a href="https://colab.research.google.com/github/ainaia/Pembelajaran_Mesin/blob/main/Tugas_Pertemuan_2_Mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = '/content/Stress-Lysis.csv'
data = pd.read_csv(dataset)
data
# Out:
#       Humidity  Temperature  Step_count  Stress_Level
# 0        21.33        90.33         123             1
# 1        21.41        90.41          93             1
# 2        27.12        96.12         196             2
# 3        27.64        96.64         177             2
# 4        10.87        79.87          87             0
# ...        ...          ...         ...           ...
# 1996     21.82        90.82          96             1
# 1997     10.45        79.45          45             0
# 1998     27.22        96.22         135             2
# 1999     12.46        81.46          64             0
# 2000     16.87        85.87          50             1
#
# [2001 rows x 4 columns]

# %%
data.head()
# Out:
#    Humidity  Temperature  Step_count  Stress_Level
# 0     21.33        90.33         123             1
# 1     21.41        90.41          93             1
# 2     27.12        96.12         196             2
# 3     27.64        96.64         177             2
# 4     10.87        79.87          87             0

# %%
print(data.dtypes)
# Out:
# Humidity        float64
# Temperature     float64
# Step_count        int64
# Stress_Level      int64
# dtype: object

# %%
datanoid = data.drop(data.columns[2],axis=1)
datanoid
# Out:
#       Humidity  Temperature  Stress_Level
# 0        21.33        90.33             1
# 1        21.41        90.41             1
# 2        27.12        96.12             2
# 3        27.64        96.64             2
# 4        10.87        79.87             0
# ...        ...          ...           ...
# 1996     21.82        90.82             1
# 1997     10.45        79.45             0
# 1998     27.22        96.22             2
# 1999     12.46        81.46             0
# 2000     16.87        85.87             1
#
# [2001 rows x 3 columns]

# %%
data.describe()
# Out:
#           Humidity  Temperature   Step_count  Stress_Level
# count  2001.000000  2001.000000  2001.000000   2001.000000
# mean     20.000000    89.000000   100.141429      1.104448
# std       5.777833     5.777833    58.182948      0.771094
# min      10.000000    79.000000     0.000000      0.000000
# 25%      15.000000    84.000000    50.000000      0.000000
# 50%      20.000000    89.000000   101.000000      1.000000
# 75%      25.000000    94.000000   150.000000      2.000000
# max      30.000000    99.000000   200.000000      2.000000

# %%
data.loc[:,"Humidity":].corr()
# Out:
#               Humidity  Temperature  Step_count  Stress_Level
# Humidity      1.000000     1.000000    0.870486      0.936036
# Temperature   1.000000     1.000000    0.870486      0.936036
# Step_count    0.870486     0.870486    1.000000      0.832623
# Stress_Level  0.936036     0.936036    0.832623      1.000000

# %%
# @title Humidity vs Temperature

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Humidity', y='Temperature', s=75, alpha=.5)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-9a35c290-4023-4b38-9c58-67f47c8cee6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a35c290-4023-4b38-9c58-67f47c8cee6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Stress-Lysis"
# Out:
# ...
# ref                              title                   size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------  ----------------------  ----  -------------------  -------------  ---------  ---------------
# jeyasrisenthil/input-data        Stress-Lysis            14KB  2023-01-06 17:31:30            919         48  0.88235295
# laavanya/stress-level-detection  Human Stress Detection   1MB  2022-02-15 15:46:46           6780         66  0.7058824

# %%
# !kaggle datasets download jeyasrisenthil/input-data
# Out:
# input-data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/input-data.zip
# Out:
# Archive:  /content/input-data.zip
#   inflating: Stress-Lysis.csv

# %%
pd.read_csv('/content/input-data.zip')
# Out:
#       Humidity  Temperature  Step_count  Stress_Level
# 0        21.33        90.33         123             1
# 1        21.41        90.41          93             1
# 2        27.12        96.12         196             2
# 3        27.64        96.64         177             2
# 4        10.87        79.87          87             0
# ...        ...          ...         ...           ...
# 1996     21.82        90.82          96             1
# 1997     10.45        79.45          45             0
# 1998     27.22        96.22         135             2
# 1999     12.46        81.46          64             0
# 2000     16.87        85.87          50             1
#
# [2001 rows x 4 columns]
